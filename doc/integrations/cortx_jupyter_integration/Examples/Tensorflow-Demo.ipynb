# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
from cortx_jupyter import read_data, write_data,write_model,read_model

# %% [markdown]
# # Load dataset from Cortx

# %%
data = read_data('ionosphere.csv')
df = read_csv(data)
df.head()
# Out:
# path downloading notebooks/test/ionosphere.csv
#    1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0  1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1  1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2  1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3  1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4  1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
#
#    0.03760  ...  -0.51171  0.41078  -0.46168  0.21266  -0.34090  0.42267  \
# 0 -0.04549  ...  -0.26569 -0.20468  -0.18401 -0.19040  -0.11593 -0.16626
# 1  0.01198  ...  -0.40220  0.58984  -0.22145  0.43100  -0.17365  0.60436
# 2  0.00000  ...   0.90695  0.51613   1.00000  1.00000  -0.20099  0.25682
# 3 -0.16399  ...  -0.65158  0.13290  -0.53206  0.02431  -0.62197 -0.05707
# 4  0.06637  ...  -0.01535 -0.03240   0.09223 -0.07859   0.00732  0.00000
#
#    -0.54487  0.18641  -0.45300  g
# 0  -0.06288 -0.13738  -0.02447  b
# 1  -0.24180  0.56045  -0.38238  g
# 2   1.00000 -0.32382   1.00000  b
# 3  -0.59573 -0.04608  -0.65697  g
# 4   0.00000 -0.00039   0.12011  b
#
# [5 rows x 35 columns]

# %% [markdown]
# # Process data

# %%
X, y = df.values[:, :-1], df.values[:, -1]

X = X.astype('float32')
y = LabelEncoder().fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

n_features = X_train.shape[1]
# Out:
# (234, 34) (116, 34) (234,) (116,)

# %% [markdown]
# # Save processed data to Cortx

# %%
write_data('processed_input_tf',X)
# Out:
# path upload notebooks/test/processed_input_tf

# %% [markdown]
# # Train the model

# %%
model = Sequential()
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=0)

# %% [markdown]
# # load pretrained model to Cortx
#
# Load a pretrained model to Cortx.
#
# This model can be shared with other collaborators who can just read the model and use it for prediction without having the perform the cleaning and training process again

# %%
write_model('tensorflow_model',model)
# Out:
# path upload notebooks/test/tensorflow_model

# %% [markdown]
# ### Loading a pretrained model for demo purpose

# %%
model = read_model('tensorflow_model')
# Out:
# path downloading notebooks/test/tensorflow_model

# %% [markdown]
# # Evaluate the model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=0)
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)

row = [1,0,0.99539,-0.05889,0.85243,0.02306,0.83398,-0.37708,1,0.03760,0.85243,-0.17755,0.59755,-0.44945,0.60536,-0.38223,0.84356,-0.38542,0.58212,-0.32192,0.56971,-0.29674,0.36946,-0.47357,0.56811,-0.51171,0.41078,-0.46168,0.21266,-0.34090,0.42267,-0.54487,0.18641,-0.45300]
yhat = model.predict([row])
print('Predicted: %.3f' % yhat)
# Out:
# Test Accuracy: 0.931
# Predicted: 0.985
